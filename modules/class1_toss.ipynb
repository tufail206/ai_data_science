# %%
import random

# %%
while True:
   
    toss=input("coin is flip").lower().strip()
    if toss=="q":
        break
    else :
     coin=random.choice(["head","tail"])
     if toss==coin:
        print("pakistan have won the toss")
     else:
        print("pakistan loss the toss")
# Out:
# pakistan loss the toss
# pakistan have won the toss
