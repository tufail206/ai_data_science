# %%
productsInStore={'soap':120,'shampo':230,'surf':300,'tooth_paste':120,'tooth_burs':400}

cart=[]
def ChaloShopping():
     menu()

# %%
def menu():
    print("welcome to Zain's Store")
    print("""what you want to do?
          1 for shopping
          2 for viewing cart
          3 for billing 
          4 quit
          """)
    option=int(input())
    if option==1:
        shopping()
    elif option==2:
        viewCart()
    elif option==3:
        billing()
    else:
        print("thank you")

# %%
def calcTax(total):
    tax=0
    if total>=100000:
        tax=total*.10
    elif total>=500000:
        tax=total*.075
    elif total>=24000:
        tax=total*0.05
    else:
        tax=total*0
    return tax
