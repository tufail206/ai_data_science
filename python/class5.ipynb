# %% [markdown]
# #### global and local name space

# %% [markdown]
# ##### global : a variable is global if can be accessed from the outside the function body
# #### local : a variable declarred inside the function and can not access outside the function

# %%
def add (a ,b):
     global c
     c=a+b
     print(c)

# %%
add(4,5)
