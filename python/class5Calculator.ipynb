# %%
def sum(a,b):
    return a+b
def sub(a,b):
    return a-b
def mult(a,b):
    return a*b
def dub(a,b):
    return a//b
def calCulate(fu,v1,v2):
    return fu(v1,v2)

result=calCulate(sum,2,3)
print(result)
# Out:
# 5
