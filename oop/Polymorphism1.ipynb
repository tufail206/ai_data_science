# %%
class Animal():
    def speak(self):
        return "animal makes sound"

# %%
a1=Animal()

# %%
a1.speak()
# Out:
# 'animal makes sound'

# %%
class Dog(Animal):
    def speak(self):
        return "dog is barking"

# %%
dog=Dog()

# %%
dog.speak()
# Out:
# 'dog is barking'
