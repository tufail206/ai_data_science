# %% [markdown]
# ##### OOP:
# oriented : a thing which revoule on certain thing
# it is basically code writing style
# object : every this object ,but in programming
# agar koyi object h toh us ki feature hoti h , jesy name , color,hegith,weight,size
# us k kuch function hoty h ki object kia karta h ,
# why we need oop
# kam sy kam code likhna padhy , program execute in less time , less code more work
# oop : object is the instance of class
#
#       class --> blue print of object
#       agar may koyi object bnany ja raha hun to wo object kesy hogi feature kia hogi or kia function hogi
#
# object ka template class h yani object may kia hogi wo hum class may define karty hain
#
# for example
#  jesy mobile 1 object h q ki is k features and function h
#
#  laikeen socho
#  agar new mobile bnana chahy toh kesy kary gi ,,,
#  pehly wo  1 model bnaye gy ki kia kia hogi is may
#  toh ye model hum class kehty hain
#       object-->
#
#       object follow the class
#       instance means copy of the class

# %%
# // how to make class ??????

# trevial--> mandatory
class Car():
    name="BMW"
    engine_cc=660
    color="Black"
    engineType="Petrol"
    transmission="Auto"
    priceInMillion=5.5

# %%
# Object
c1=Car()
c2=Car()
c3=Car()
c4=Car()

# %%
print (type(c1))
# Out:
# <class '__main__.Car'>

# %%
c1.color
# Out:
# 'Black'
