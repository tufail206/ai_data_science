# %%
class Animal():
 def   __init__(self,typ,color,name):
        self.typ=typ
        self.color=color
        self.name=name

 def details(self):
    return f""""i am {self.typ} of  animal 
               my color is {self.color} and 
               my name is {self.name}
              """

# %%
class Cat(Animal):
    def __init__(self,typ,color,name,character,age,sound):
        super().__init__(typ,color,name)
        self.character=character
        self.age=age
        self.sound=sound
        # //this is function override we overwrite the property
    def details(self):
           return {self.name,self.color , self.character}

# %%
# Out:
# '"i am bili of  animal \n               my color is brown and \n               my name is BiLLA\n              '

# %%
c=Cat("chota","white","billi","shararati",4,"miewooo")
c.Details()
# Out:
# {'"i am chota of  animal \n               my color is white and \n               my name is billi\n              ',
#  'shararati'}
