# %%
# function and values dynamic in in oop
#but not in normal function 

# Constructor it will initializer  
#in initializer we initialize the things that is mandatory 
# dendar __ 
class Car():
    def __init__(self,make,model,year,engine_cc,color,transmission):
        #attributes of the function//characteristic
        self.make=make
        self.model=model
        self.year=year
        self.engine_cc=engine_cc
        self.color=color
        self.transmission=transmission
#initilizer call when object created --> call automatically

    #function
    def start(self):
        return f"{self.color} {self.make} {self.model} is start "
    #if we dont create initializer then it created automatically 
    #like def __init__(self)

# %%
# create obj
myCar=Car("Honda","Civic",2024,1800,"Black","Auto")

# %%
yourCar=Car("KIA","SportAge",2022,2000,"White","Auto")

# %%
  # self
    # self may khut object ja raha hota h 

    # check karny k liye
    # object

# yourCar=Car("KIA","SportAge",2022,2000,"White","Auto","4 wheel")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 7
#       1   # self
#       2     # self may khut object ja raha hota h
#       3
#       4     # check karny k liye
#       5     # object
# ----> 7 yourCar=Car("KIA","SportAge",2022,2000,"White","Auto","4 wheel")
#
# TypeError: Car.__init__() takes 7 positional arguments but 8 were given

# %%
myCar.start()
# Out:
# 'Black Honda Civic is start '

# %% [markdown]
# even though we can access from the class but we need to pass the object in the place of self

# %%
Car.start(myCar)
# Out:
# 'Black Honda Civic is start '
